# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import umap

# Load normalized proteomics data
proteomics = pd.read_csv(
    r"C:\Users\za945\OneDrive\Desktop\project\data\luad_proteomics_normalized.csv",
    index_col=0
)

# Load clinical data
clinical = pd.read_csv(
    r"C:\Users\za945\OneDrive\Desktop\project\data\luad_clinical.csv",
    index_col=0
)

# Align samples
common_samples = proteomics.index.intersection(clinical.index)
proteomics = proteomics.loc[common_samples]
clinical = clinical.loc[common_samples]

print("Proteomics shape:", proteomics.shape)
print("Clinical shape:", clinical.shape)
print()
print("Data loaded! ✅")
